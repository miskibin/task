# %%
# Imports and helper utilities
import pandas as pd
import numpy as np
import re
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

DATA_PATH = Path().cwd().parent / 'data' / 'transit_events.csv'
df = pd.read_csv(DATA_PATH, parse_dates=['event_ts'], low_memory=False)
df

# %%
# Out:
#         shipment_id            event_ts location_type      event_status
# 0       SH-00145406 2023-01-01 00:00:00    On Vehicle            Picked
# 1       SH-00074867 2023-01-01 00:00:00  Regional Hub  Out for Delivery
# 2       SH-00132727 2023-01-01 00:00:00   Destination        In Transit
# 3       SH-00196731 2023-01-01 00:00:00       Seaport  Out for Delivery
# 4       SH-00061224 2023-01-01 00:00:00       Airport        In Transit
# ...             ...                 ...           ...               ...
# 399995  SH-00026250 2025-10-30 23:00:00      Final DC        In Transit
# 399996  SH-00199670 2025-10-30 23:00:00       Customs      Customs Hold
# 399997  SH-00209773 2025-10-30 23:00:00       Airport         Delivered
# 399998  SH-00064076 2025-10-30 23:00:00       Airport   Departed Origin
# 399999  SH-00040201 2025-10-30 23:00:00      Final DC  Out for Delivery
#
# [400000 rows x 4 columns]
